# %% [markdown]
# ![dt1.PNG](attachment:dt1.PNG)

# %% [markdown]
# ![dt2.PNG](attachment:dt2.PNG)

# %% [markdown]
# ![dt3.PNG](attachment:dt3.PNG)

# %% [markdown]
# ![dt4.PNG](attachment:dt4.PNG)

# %% [markdown]
# ![dt5.PNG](attachment:dt5.PNG)

# %% [markdown]
# ![dt6.PNG](attachment:dt6.PNG)

# %% [markdown]
# ![dt7.PNG](attachment:dt7.PNG)

# %% [markdown]
# ![dt8.PNG](attachment:dt8.PNG)
